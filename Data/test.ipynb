# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from Caulimate.Data.SimCoords import simulate_uniform_coords

# Example usage
num_points = 10
extent = [-180, 18, -90, 90]  # Global extent for demonstration
uniform_coords = simulate_uniform_coords(num_points, extent, 42)

# Plotting
fig, ax = plt.subplots(figsize=(12, 6), subplot_kw={'projection': ccrs.PlateCarree()})
ax.set_extent(extent)
ax.coastlines()
ax.scatter(*zip(*uniform_coords), s=10, color='red', transform=ccrs.Geodetic(), label='Approx Uniformly Distributed Points')
ax.set_title('Approximately Uniformly Distributed Coordinates')
plt.legend()
plt.show()
